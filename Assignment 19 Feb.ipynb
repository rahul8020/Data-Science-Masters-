# %% [markdown]
# ### Assignment 19 Feb

# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# #### Flask is a micro web framework for Python that allows you to build web applications quickly and with minimal boilerplate code
# #### It is a lightweight framework that offers hassle-free development.
# #### Provide flexibility to the developer to experiment with their modules or architecture.
# #### It is suitable for small projects.
# #### Offers a built-in development server and fast debugger.
# #### 3 Easily scalable for the applications.

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output inJupyter Notebook.

# %% [markdown]
# ![19feb.PNG](attachment:19feb.PNG)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# #### App Routing means mapping the URLs to a specific function that will handle the logic for that URL.
# #### It help users remember application URLs. It is helpful to access the desired page directly without navigating from the home page

# %% [markdown]
# ![as%20192.PNG](attachment:as%20192.PNG)

# %% [markdown]
# ![19feb33.PNG](attachment:19feb33.PNG)

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of theurl_for() function.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/hello/<name>')
def hello(name):
    return f'Hello, {name}!'

@app.route('/')
def index():
    url = url_for('hello', name='Rahul')
    return f'Click <a href="{url}">here</a> to greet Rahul Sir'


app.run()
